# %%
import torch

# %%
print("Is CUDA available?", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
print("Number of GPUs:", torch.cuda.device_count())
print("GPU Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU found")
# Out:
# Is CUDA available? True
# CUDA version: 11.8
# Number of GPUs: 1
# GPU Name: NVIDIA GeForce RTX 4060 Laptop GPU

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # Assign GPU index (0 if you have one GPU)

# %%
# Verify nnUNet GPU Utilization, By default, nnUNet will use the GPU if available
import torch
print("Using CUDA:", torch.cuda.is_available())
print("Current device:", torch.cuda.current_device())
print("Device Name:", torch.cuda.get_device_name(torch.cuda.current_device()))
# Out:
# Using CUDA: True
# Current device: 0
# Device Name: NVIDIA GeForce RTX 4060 Laptop GPU

# %%
import os

print("nnUNet_raw:", os.environ.get("nnUNet_raw"))
print("nnUNet_preprocessed:", os.environ.get("nnUNet_preprocessed"))
print("nnUNet_results:", os.environ.get("nnUNet_results"))
# Out:
# nnUNet_raw: C:\Users\clarynse\NasalSeg\nnUNet_raw
# nnUNet_preprocessed: C:\Users\clarynse\NasalSeg\nnUNet_preprocessed
# nnUNet_results: C:\Users\clarynse\NasalSeg\nnUNet_results

# %%
import os

# Define paths
converted_dataset_path = "C:/Users/clarynse/NasalSeg/nnUNet_raw/Dataset123_NasalSeg"
converted_imagesTr_path = os.path.join(converted_dataset_path, "imagesTr")
converted_labelsTr_path = os.path.join(converted_dataset_path, "labelsTr")

# Check if required directories exist
print("Converted Dataset Path Exists:", os.path.exists(converted_dataset_path))
print("Converted imagesTr Exists:", os.path.exists(converted_imagesTr_path))
print("Converted labelsTr Exists:", os.path.exists(converted_labelsTr_path))

# List files in imagesTr and labelsTr
print("\nFiles in imagesTr:", os.listdir(converted_imagesTr_path)[:10])  # Print first 10 files
print("\nFiles in labelsTr:", os.listdir(converted_labelsTr_path)[:10])  # Print first 10 files
# Out:
# Converted Dataset Path Exists: True
# Converted imagesTr Exists: True
# Converted labelsTr Exists: True
#
# Files in imagesTr: ['P_001_0000.nii.gz', 'P_002_0000.nii.gz', 'P_003_0000.nii.gz', 'P_004_0000.nii.gz', 'P_005_0000.nii.gz', 'P_006_0000.nii.gz', 'P_007_0000.nii.gz', 'P_008_0000.nii.gz', 'P_009_0000.nii.gz', 'P_010_0000.nii.gz']
#
# Files in labelsTr: ['P_001.nii.gz', 'P_002.nii.gz', 'P_003.nii.gz', 'P_004.nii.gz', 'P_005.nii.gz', 'P_006.nii.gz', 'P_007.nii.gz', 'P_008.nii.gz', 'P_009.nii.gz', 'P_010.nii.gz']

# %%
pip install batchgenerators
# Out:
# Requirement already satisfied: batchgenerators in c:\users\clarynse\appdata\roaming\python\python312\site-packages (0.25.1)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\clarynse\anaconda3\lib\site-packages (from batchgenerators) (10.4.0)
# Requirement already satisfied: numpy>=1.10.2 in c:\users\clarynse\anaconda3\lib\site-packages (from batchgenerators) (1.26.4)
# Requirement already satisfied: scipy in c:\users\clarynse\anaconda3\lib\site-packages (from batchgenerators) (1.13.1)
# Requirement already satisfied: scikit-image in c:\users\clarynse\anaconda3\lib\site-packages (from batchgenerators) (0.24.0)
# Requirement already satisfied: scikit-learn in c:\users\clarynse\anaconda3\lib\site-packages (from batchgenerators) (1.5.1)
# Requirement already satisfied: future in c:\users\clarynse\appdata\roaming\python\python312\site-packages (from batchgenerators) (1.0.0)
# Requirement already satisfied: pandas in c:\users\clarynse\anaconda3\lib\site-packages (from batchgenerators) (2.2.2)
# Requirement already satisfied: unittest2 in c:\users\clarynse\appdata\roaming\python\python312\site-packages (from batchgenerators) (1.1.0)
# Requirement already satisfied: threadpoolctl in c:\users\clarynse\anaconda3\lib\site-packages (from batchgenerators) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\clarynse\anaconda3\lib\site-packages (from pandas->batchgenerators) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\clarynse\anaconda3\lib\site-packages (from pandas->batchgenerators) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\clarynse\anaconda3\lib\site-packages (from pandas->batchgenerators) (2023.3)
# Requirement already satisfied: networkx>=2.8 in c:\users\clarynse\anaconda3\lib\site-packages (from scikit-image->batchgenerators) (3.3)
# Requirement already satisfied: imageio>=2.33 in c:\users\clarynse\anaconda3\lib\site-packages (from scikit-image->batchgenerators) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\clarynse\anaconda3\lib\site-packages (from scikit-image->batchgenerators) (2023.4.12)
# Requirement already satisfied: packaging>=21 in c:\users\clarynse\anaconda3\lib\site-packages (from scikit-image->batchgenerators) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\clarynse\anaconda3\lib\site-packages (from scikit-image->batchgenerators) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\clarynse\anaconda3\lib\site-packages (from scikit-learn->batchgenerators) (1.4.2)
# Collecting argparse (from unittest2->batchgenerators)
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: six>=1.4 in c:\users\clarynse\anaconda3\lib\site-packages (from unittest2->batchgenerators) (1.16.0)
# Requirement already satisfied: traceback2 in c:\users\clarynse\appdata\roaming\python\python312\site-packages (from unittest2->batchgenerators) (1.4.0)
# Requirement already satisfied: linecache2 in c:\users\clarynse\appdata\roaming\python\python312\site-packages (from traceback2->unittest2->batchgenerators) (1.0.0)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~nunetv2 (C:\Users\clarynse\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~nunetv2 (C:\Users\clarynse\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~nunetv2 (C:\Users\clarynse\anaconda3\Lib\site-packages)

# %%
import os
import nrrd
import nibabel as nib
import numpy as np
import SimpleITK as sitk

# %%
# Define paths
dataset_path = "C:/Users/clarynse/NasalSeg/nnUNet_raw/Dataset123_NasalSeg"
imagesTr_path = os.path.join(dataset_path, "imagesTr")
labelsTr_path = os.path.join(dataset_path, "labelsTr")

# %%
final_imagesTr_path = os.path.join(dataset_path, "imagesTr")
final_labelsTr_path = os.path.join(dataset_path, "labelsTr")

# %%
# Ensure final directories exist
os.makedirs(final_imagesTr_path, exist_ok=True)
os.makedirs(final_labelsTr_path, exist_ok=True)

# %%
import os

# Define paths
final_imagesTr_path = "C:/Users/clarynse/NasalSeg/nnUNet_raw/Dataset123_NasalSeg/imagesTr"
final_labelsTr_path = "C:/Users/clarynse/NasalSeg/nnUNet_raw/Dataset123_NasalSeg/labelsTr"

# %%
print("Final imagesTr:", os.listdir(final_imagesTr_path))
print("Final labelsTr:", os.listdir(final_labelsTr_path))
# Out:
# Final imagesTr: ['P_001_0000.nii.gz', 'P_002_0000.nii.gz', 'P_003_0000.nii.gz', 'P_004_0000.nii.gz', 'P_005_0000.nii.gz', 'P_006_0000.nii.gz', 'P_007_0000.nii.gz', 'P_008_0000.nii.gz', 'P_009_0000.nii.gz', 'P_010_0000.nii.gz', 'P_011_0000.nii.gz', 'P_012_0000.nii.gz', 'P_013_0000.nii.gz', 'P_014_0000.nii.gz', 'P_015_0000.nii.gz', 'P_016_0000.nii.gz', 'P_017_0000.nii.gz', 'P_018_0000.nii.gz', 'P_019_0000.nii.gz', 'P_020_0000.nii.gz', 'P_021_0000.nii.gz', 'P_022_0000.nii.gz', 'P_023_0000.nii.gz', 'P_024_0000.nii.gz', 'P_025_0000.nii.gz', 'P_026_0000.nii.gz', 'P_027_0000.nii.gz', 'P_028_0000.nii.gz', 'P_029_0000.nii.gz', 'P_030_0000.nii.gz', 'P_031_0000.nii.gz', 'P_032_0000.nii.gz', 'P_033_0000.nii.gz', 'P_034_0000.nii.gz', 'P_035_0000.nii.gz', 'P_036_0000.nii.gz', 'P_037_0000.nii.gz', 'P_038_0000.nii.gz', 'P_039_0000.nii.gz', 'P_040_0000.nii.gz', 'P_041_0000.nii.gz', 'P_042_0000.nii.gz', 'P_043_0000.nii.gz', 'P_044_0000.nii.gz', 'P_045_0000.nii.gz', 'P_046_0000.nii.gz', 'P_047_0000.nii.gz', 'P_048_0000.nii.gz', 'P_049_0000.nii.gz', 'P_050_0000.nii.gz', 'P_051_0000.nii.gz', 'P_052_0000.nii.gz', 'P_053_0000.nii.gz', 'P_054_0000.nii.gz', 'P_055_0000.nii.gz', 'P_056_0000.nii.gz', 'P_057_0000.nii.gz', 'P_058_0000.nii.gz', 'P_059_0000.nii.gz', 'P_060_0000.nii.gz', 'P_061_0000.nii.gz', 'P_062_0000.nii.gz', 'P_063_0000.nii.gz', 'P_064_0000.nii.gz', 'P_065_0000.nii.gz', 'P_066_0000.nii.gz', 'P_067_0000.nii.gz', 'P_068_0000.nii.gz', 'P_069_0000.nii.gz', 'P_070_0000.nii.gz', 'P_071_0000.nii.gz', 'P_072_0000.nii.gz', 'P_073_0000.nii.gz', 'P_074_0000.nii.gz', 'P_075_0000.nii.gz', 'P_076_0000.nii.gz', 'P_077_0000.nii.gz', 'P_078_0000.nii.gz', 'P_079_0000.nii.gz', 'P_080_0000.nii.gz', 'P_081_0000.nii.gz', 'P_082_0000.nii.gz', 'P_083_0000.nii.gz', 'P_084_0000.nii.gz', 'P_085_0000.nii.gz', 'P_086_0000.nii.gz', 'P_087_0000.nii.gz', 'P_088_0000.nii.gz', 'P_089_0000.nii.gz', 'P_090_0000.nii.gz', 'P_091_0000.nii.gz', 'P_092_0000.nii.gz', 'P_093_0000.nii.gz', 'P_094_0000.nii.gz', 'P_095_0000.nii.gz', 'P_096_0000.nii.gz', 'P_097_0000.nii.gz', 'P_098_0000.nii.gz', 'P_099_0000.nii.gz', 'P_100_0000.nii.gz', 'P_101_0000.nii.gz', 'P_102_0000.nii.gz', 'P_103_0000.nii.gz', 'P_104_0000.nii.gz', 'P_105_0000.nii.gz', 'P_106_0000.nii.gz', 'P_107_0000.nii.gz', 'P_108_0000.nii.gz', 'P_109_0000.nii.gz', 'P_110_0000.nii.gz', 'P_111_0000.nii.gz', 'P_112_0000.nii.gz', 'P_113_0000.nii.gz', 'P_114_0000.nii.gz', 'P_115_0000.nii.gz', 'P_116_0000.nii.gz', 'P_117_0000.nii.gz', 'P_118_0000.nii.gz', 'P_119_0000.nii.gz', 'P_120_0000.nii.gz', 'P_121_0000.nii.gz', 'P_122_0000.nii.gz', 'P_123_0000.nii.gz', 'P_124_0000.nii.gz', 'P_125_0000.nii.gz', 'P_126_0000.nii.gz', 'P_127_0000.nii.gz', 'P_128_0000.nii.gz', 'P_129_0000.nii.gz', 'P_130_0000.nii.gz']
# Final labelsTr: ['P_001.nii.gz', 'P_002.nii.gz', 'P_003.nii.gz', 'P_004.nii.gz', 'P_005.nii.gz', 'P_006.nii.gz', 'P_007.nii.gz', 'P_008.nii.gz', 'P_009.nii.gz', 'P_010.nii.gz', 'P_011.nii.gz', 'P_012.nii.gz', 'P_013.nii.gz', 'P_014.nii.gz', 'P_015.nii.gz', 'P_016.nii.gz', 'P_017.nii.gz', 'P_018.nii.gz', 'P_019.nii.gz', 'P_020.nii.gz', 'P_021.nii.gz', 'P_022.nii.gz', 'P_023.nii.gz', 'P_024.nii.gz', 'P_025.nii.gz', 'P_026.nii.gz', 'P_027.nii.gz', 'P_028.nii.gz', 'P_029.nii.gz', 'P_030.nii.gz', 'P_031.nii.gz', 'P_032.nii.gz', 'P_033.nii.gz', 'P_034.nii.gz', 'P_035.nii.gz', 'P_036.nii.gz', 'P_037.nii.gz', 'P_038.nii.gz', 'P_039.nii.gz', 'P_040.nii.gz', 'P_041.nii.gz', 'P_042.nii.gz', 'P_043.nii.gz', 'P_044.nii.gz', 'P_045.nii.gz', 'P_046.nii.gz', 'P_047.nii.gz', 'P_048.nii.gz', 'P_049.nii.gz', 'P_050.nii.gz', 'P_051.nii.gz', 'P_052.nii.gz', 'P_053.nii.gz', 'P_054.nii.gz', 'P_055.nii.gz', 'P_056.nii.gz', 'P_057.nii.gz', 'P_058.nii.gz', 'P_059.nii.gz', 'P_060.nii.gz', 'P_061.nii.gz', 'P_062.nii.gz', 'P_063.nii.gz', 'P_064.nii.gz', 'P_065.nii.gz', 'P_066.nii.gz', 'P_067.nii.gz', 'P_068.nii.gz', 'P_069.nii.gz', 'P_070.nii.gz', 'P_071.nii.gz', 'P_072.nii.gz', 'P_073.nii.gz', 'P_074.nii.gz', 'P_075.nii.gz', 'P_076.nii.gz', 'P_077.nii.gz', 'P_078.nii.gz', 'P_079.nii.gz', 'P_080.nii.gz', 'P_081.nii.gz', 'P_082.nii.gz', 'P_083.nii.gz', 'P_084.nii.gz', 'P_085.nii.gz', 'P_086.nii.gz', 'P_087.nii.gz', 'P_088.nii.gz', 'P_089.nii.gz', 'P_090.nii.gz', 'P_091.nii.gz', 'P_092.nii.gz', 'P_093.nii.gz', 'P_094.nii.gz', 'P_095.nii.gz', 'P_096.nii.gz', 'P_097.nii.gz', 'P_098.nii.gz', 'P_099.nii.gz', 'P_100.nii.gz', 'P_101.nii.gz', 'P_102.nii.gz', 'P_103.nii.gz', 'P_104.nii.gz', 'P_105.nii.gz', 'P_106.nii.gz', 'P_107.nii.gz', 'P_108.nii.gz', 'P_109.nii.gz', 'P_110.nii.gz', 'P_111.nii.gz', 'P_112.nii.gz', 'P_113.nii.gz', 'P_114.nii.gz', 'P_115.nii.gz', 'P_116.nii.gz', 'P_117.nii.gz', 'P_118.nii.gz', 'P_119.nii.gz', 'P_120.nii.gz', 'P_121.nii.gz', 'P_122.nii.gz', 'P_123.nii.gz', 'P_124.nii.gz', 'P_125.nii.gz', 'P_126.nii.gz', 'P_127.nii.gz', 'P_128.nii.gz', 'P_129.nii.gz', 'P_130.nii.gz']

# %%
import os

dataset_path = "C:/Users/clarynse/NasalSeg/nnUNet_raw/Dataset123_NasalSeg"

# Check required folders
required_folders = ["imagesTr", "labelsTr"]
for folder in required_folders:
    folder_path = os.path.join(dataset_path, folder)
    print(f"{folder} Exists:", os.path.exists(folder_path))

# Check dataset.json
dataset_json_path = os.path.join(dataset_path, "dataset.json")
print("dataset.json Exists:", os.path.exists(dataset_json_path))

# List files in imagesTr and labelsTr
print("\nFinal imagesTr:", os.listdir(os.path.join(dataset_path, "imagesTr"))[:10])  # Show first 10 files
print("Final labelsTr:", os.listdir(os.path.join(dataset_path, "labelsTr"))[:10])  # Show first 10 files
# Out:
# imagesTr Exists: True
# labelsTr Exists: True
# dataset.json Exists: True
#
# Final imagesTr: ['P_001_0000.nii.gz', 'P_002_0000.nii.gz', 'P_003_0000.nii.gz', 'P_004_0000.nii.gz', 'P_005_0000.nii.gz', 'P_006_0000.nii.gz', 'P_007_0000.nii.gz', 'P_008_0000.nii.gz', 'P_009_0000.nii.gz', 'P_010_0000.nii.gz']
# Final labelsTr: ['P_001.nii.gz', 'P_002.nii.gz', 'P_003.nii.gz', 'P_004.nii.gz', 'P_005.nii.gz', 'P_006.nii.gz', 'P_007.nii.gz', 'P_008.nii.gz', 'P_009.nii.gz', 'P_010.nii.gz']

# %%
import json
import os
from nnunetv2.dataset_conversion.generate_dataset_json import generate_dataset_json

# Define dataset path
dataset_path = "C:/Users/clarynse/NasalSeg/nnUNet_raw/Dataset123_NasalSeg"

# Get the list of all image cases
image_files = sorted(os.listdir(os.path.join(dataset_path, "imagesTr")))
label_files = sorted(os.listdir(os.path.join(dataset_path, "labelsTr")))

# Ensure that every image has a corresponding label
image_cases = {f.split("_")[0] for f in image_files}  # Extract case ID from images
label_cases = {f.split(".")[0] for f in label_files}  # Extract case ID from labels

if image_cases != label_cases:
    print("❌ Error: Image and label cases do not match!")
    print("Missing labels:", image_cases - label_cases)
    print("Missing images:", label_cases - image_cases)
else:
    print("✅ All image-label pairs are correctly matched!")

# Define dataset properties
channel_names = {0: "CT"}  # Single-channel CT images
labels = {
    "background": 0,
    "left_nasal_cavity": 1,
    "right_nasal_cavity": 2,
    "nasal_pharynx": 3,
    "left_maxillary_sinus": 4,
    "right_maxillary_sinus": 5
}
num_training_cases = len(image_files)
file_ending = ".nii.gz"

# Create the list of training cases
training_cases = []
for case in sorted(image_cases):
    training_cases.append({
        "image": f"./imagesTr/{case}_0000.nii.gz",
        "label": f"./labelsTr/{case}.nii.gz"
    })

# Create the dataset.json structure
dataset_json = {
    "channel_names": channel_names,
    "labels": labels,
    "numTraining": num_training_cases,
    "file_ending": file_ending,
    "name": "NasalSeg",
    "reference": "https://github.com/YichiZhang98/NasalSeg",
    "licence": "Open License",
    "training": training_cases  # Now explicitly includes all cases
}

# Save dataset.json
dataset_json_path = os.path.join(dataset_path, "dataset.json")
with open(dataset_json_path, "w") as f:
    json.dump(dataset_json, f, indent=4)

# Verify JSON file
if os.path.exists(dataset_json_path):
    print("✅ dataset.json successfully updated with all cases!")
    with open(dataset_json_path, "r") as f:
        print(json.dumps(json.load(f), indent=4))
else:
    print("❌ dataset.json was not created. Check for errors.")
# Out:
# ✅ All image-label pairs are correctly matched!
# ✅ dataset.json successfully updated with all cases!
# {
#     "channel_names": {
#         "0": "CT"
#     },
#     "labels": {
#         "background": 0,
#         "left_nasal_cavity": 1,
#         "right_nasal_cavity": 2,
#         "nasal_pharynx": 3,
#         "left_maxillary_sinus": 4,
#         "right_maxillary_sinus": 5
#     },
#     "numTraining": 130,
#     "file_ending": ".nii.gz",
#     "name": "NasalSeg",
#     "reference": "https://github.com/YichiZhang98/NasalSeg",
#     "licence": "Open License",
#     "training": [
#         {
#             "image": "./imagesTr/P001_0000.nii.gz",
#             "label": "./labelsTr/P001.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P002_0000.nii.gz",
#             "label": "./labelsTr/P002.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P003_0000.nii.gz",
#             "label": "./labelsTr/P003.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P004_0000.nii.gz",
#             "label": "./labelsTr/P004.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P005_0000.nii.gz",
#             "label": "./labelsTr/P005.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P006_0000.nii.gz",
#             "label": "./labelsTr/P006.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P007_0000.nii.gz",
#             "label": "./labelsTr/P007.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P008_0000.nii.gz",
#             "label": "./labelsTr/P008.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P009_0000.nii.gz",
#             "label": "./labelsTr/P009.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P010_0000.nii.gz",
#             "label": "./labelsTr/P010.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P011_0000.nii.gz",
#             "label": "./labelsTr/P011.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P012_0000.nii.gz",
#             "label": "./labelsTr/P012.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P013_0000.nii.gz",
#             "label": "./labelsTr/P013.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P014_0000.nii.gz",
#             "label": "./labelsTr/P014.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P015_0000.nii.gz",
#             "label": "./labelsTr/P015.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P016_0000.nii.gz",
#             "label": "./labelsTr/P016.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P017_0000.nii.gz",
#             "label": "./labelsTr/P017.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P018_0000.nii.gz",
#             "label": "./labelsTr/P018.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P019_0000.nii.gz",
#             "label": "./labelsTr/P019.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P020_0000.nii.gz",
#             "label": "./labelsTr/P020.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P021_0000.nii.gz",
#             "label": "./labelsTr/P021.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P022_0000.nii.gz",
#             "label": "./labelsTr/P022.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P023_0000.nii.gz",
#             "label": "./labelsTr/P023.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P024_0000.nii.gz",
#             "label": "./labelsTr/P024.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P025_0000.nii.gz",
#             "label": "./labelsTr/P025.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P026_0000.nii.gz",
#             "label": "./labelsTr/P026.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P027_0000.nii.gz",
#             "label": "./labelsTr/P027.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P028_0000.nii.gz",
#             "label": "./labelsTr/P028.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P029_0000.nii.gz",
#             "label": "./labelsTr/P029.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P030_0000.nii.gz",
#             "label": "./labelsTr/P030.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P031_0000.nii.gz",
#             "label": "./labelsTr/P031.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P032_0000.nii.gz",
#             "label": "./labelsTr/P032.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P033_0000.nii.gz",
#             "label": "./labelsTr/P033.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P034_0000.nii.gz",
#             "label": "./labelsTr/P034.nii.gz"
#         },
#         {
#             "image": "./imagesTr/
nii.gz"
#         },
#         {
#             "image": "./imagesTr/P086_0000.nii.gz",
#             "label": "./labelsTr/P086.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P087_0000.nii.gz",
#             "label": "./labelsTr/P087.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P088_0000.nii.gz",
#             "label": "./labelsTr/P088.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P089_0000.nii.gz",
#             "label": "./labelsTr/P089.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P090_0000.nii.gz",
#             "label": "./labelsTr/P090.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P091_0000.nii.gz",
#             "label": "./labelsTr/P091.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P092_0000.nii.gz",
#             "label": "./labelsTr/P092.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P093_0000.nii.gz",
#             "label": "./labelsTr/P093.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P094_0000.nii.gz",
#             "label": "./labelsTr/P094.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P095_0000.nii.gz",
#             "label": "./labelsTr/P095.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P096_0000.nii.gz",
#             "label": "./labelsTr/P096.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P097_0000.nii.gz",
#             "label": "./labelsTr/P097.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P098_0000.nii.gz",
#             "label": "./labelsTr/P098.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P099_0000.nii.gz",
#             "label": "./labelsTr/P099.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P100_0000.nii.gz",
#             "label": "./labelsTr/P100.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P101_0000.nii.gz",
#             "label": "./labelsTr/P101.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P102_0000.nii.gz",
#             "label": "./labelsTr/P102.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P103_0000.nii.gz",
#             "label": "./labelsTr/P103.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P104_0000.nii.gz",
#             "label": "./labelsTr/P104.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P105_0000.nii.gz",
#             "label": "./labelsTr/P105.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P106_0000.nii.gz",
#             "label": "./labelsTr/P106.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P107_0000.nii.gz",
#             "label": "./labelsTr/P107.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P108_0000.nii.gz",
#             "label": "./labelsTr/P108.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P109_0000.nii.gz",
#             "label": "./labelsTr/P109.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P110_0000.nii.gz",
#             "label": "./labelsTr/P110.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P111_0000.nii.gz",
#             "label": "./labelsTr/P111.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P112_0000.nii.gz",
#             "label": "./labelsTr/P112.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P113_0000.nii.gz",
#             "label": "./labelsTr/P113.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P114_0000.nii.gz",
#             "label": "./labelsTr/P114.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P115_0000.nii.gz",
#             "label": "./labelsTr/P115.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P116_0000.nii.gz",
#             "label": "./labelsTr/P116.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P117_0000.nii.gz",
#             "label": "./labelsTr/P117.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P118_0000.nii.gz",
#             "label": "./labelsTr/P118.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P119_0000.nii.gz",
#             "label": "./labelsTr/P119.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P120_0000.nii.gz",
#             "label": "./labelsTr/P120.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P121_0000.nii.gz",
#             "label": "./labelsTr/P121.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P122_0000.nii.gz",
#             "label": "./labelsTr/P122.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P123_0000.nii.gz",
#             "label": "./labelsTr/P123.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P124_0000.nii.gz",
#             "label": "./labelsTr/P124.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P125_0000.nii.gz",
#             "label": "./labelsTr/P125.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P126_0000.nii.gz",
#             "label": "./labelsTr/P126.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P127_0000.nii.gz",
#             "label": "./labelsTr/P127.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P128_0000.nii.gz",
#             "label": "./labelsTr/P128.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P129_0000.nii.gz",
#             "label": "./labelsTr/P129.nii.gz"
#         },
#         {
#             "image": "./imagesTr/P130_0000.nii.gz",
#             "label": "./labelsTr/P130.nii.gz"
#         }
#     ]
# }

# %%
import subprocess

# Define the command
preprocessing_command = ["nnUNetv2_plan_and_preprocess", "-d", "123", "--verify_dataset_integrity"]

# Run the command in Jupyter
process = subprocess.run(preprocessing_command, capture_output=True, text=True)

# Print the output
print(process.stdout)
print(process.stderr)
# Out:
# Fingerprint extraction...
# Dataset123_NasalSeg
# Using <class 'nnunetv2.imageio.simpleitk_reader_writer.SimpleITKIO'> as reader/writer
#
# ####################
# verify_dataset_integrity Done.
# If you didn't see any error messages then your dataset is most likely OK!
# ####################
#
# Experiment planning...
#
# ############################
# INFO: You are using the old nnU-Net default planner. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Dropping 3d_lowres config because the image size difference to 3d_fullres is too small. 3d_fullres: [ 51.  186.5 152. ], 3d_lowres: [51, 186, 152]
# 2D U-Net configuration:
# {'data_identifier': 'nnUNetPlans_2d', 'preprocessor_name': 'DefaultPreprocessor', 'batch_size': 105, 'patch_size': (192, 160), 'median_image_size_in_voxels': array([186.5, 152. ]), 'spacing': array([1., 1.]), 'normalization_schemes': ['CTNormalization'], 'use_mask_for_norm': [False], 'resampling_fn_data': 'resample_data_or_seg_to_shape', 'resampling_fn_seg': 'resample_data_or_seg_to_shape', 'resampling_fn_data_kwargs': {'is_seg': False, 'order': 3, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_seg_kwargs': {'is_seg': True, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_probabilities': 'resample_data_or_seg_to_shape', 'resampling_fn_probabilities_kwargs': {'is_seg': False, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'architecture': {'network_class_name': 'dynamic_network_architectures.architectures.unet.PlainConvUNet', 'arch_kwargs': {'n_stages': 6, 'features_per_stage': (32, 64, 128, 256, 512, 512), 'conv_op': 'torch.nn.modules.conv.Conv2d', 'kernel_sizes': ((3, 3), (3, 3), (3, 3), (3, 3), (3, 3), (3, 3)), 'strides': ((1, 1), (2, 2), (2, 2), (2, 2), (2, 2), (2, 2)), 'n_conv_per_stage': (2, 2, 2, 2, 2, 2), 'n_conv_per_stage_decoder': (2, 2, 2, 2, 2), 'conv_bias': True, 'norm_op': 'torch.nn.modules.instancenorm.InstanceNorm2d', 'norm_op_kwargs': {'eps': 1e-05, 'affine': True}, 'dropout_op': None, 'dropout_op_kwargs': None, 'nonlin': 'torch.nn.LeakyReLU', 'nonlin_kwargs': {'inplace': True}}, '_kw_requires_import': ('conv_op', 'norm_op', 'dropout_op', 'nonlin')}, 'batch_dice': True}
#
# Using <class 'nnunetv2.imageio.simpleitk_reader_writer.SimpleITKIO'> as reader/writer
# 3D fullres U-Net configuration:
# {'data_identifier': 'nnUNetPlans_3d_fullres', 'preprocessor_name': 'DefaultPreprocessor', 'batch_size': 3, 'patch_size': (56, 192, 160), 'median_image_size_in_voxels': array([ 51. , 186.5, 152. ]), 'spacing': array([1., 1., 1.]), 'normalization_schemes': ['CTNormalization'], 'use_mask_for_norm': [False], 'resampling_fn_data': 'resample_data_or_seg_to_shape', 'resampling_fn_seg': 'resample_data_or_seg_to_shape', 'resampling_fn_data_kwargs': {'is_seg': False, 'order': 3, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_seg_kwargs': {'is_seg': True, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_probabilities': 'resample_data_or_seg_to_shape', 'resampling_fn_probabilities_kwargs': {'is_seg': False, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'architecture': {'network_class_name': 'dynamic_network_architectures.architectures.unet.PlainConvUNet', 'arch_kwargs': {'n_stages': 6, 'features_per_stage': (32, 64, 128, 256, 320, 320), 'conv_op': 'torch.nn.modules.conv.Conv3d', 'kernel_sizes': ((3, 3, 3), (3, 3, 3), (3, 3, 3), (3, 3, 3), (3, 3, 3), (3, 3, 3)), 'strides': ((1, 1, 1), (2, 2, 2), (2, 2, 2), (2, 2, 2), (1, 2, 2), (1, 2, 2)), 'n_conv_per_stage': (2, 2, 2, 2, 2, 2), 'n_conv_per_stage_decoder': (2, 2, 2, 2, 2), 'conv_bias': True, 'norm_op': 'torch.nn.modules.instancenorm.InstanceNorm3d', 'norm_op_kwargs': {'eps': 1e-05, 'affine': True}, 'dropout_op': None, 'dropout_op_kwargs': None, 'nonlin': 'torch.nn.LeakyReLU', 'nonlin_kwargs': {'inplace': True}}, '_kw_requires_import': ('conv_op', 'norm_op', 'dropout_op', 'nonlin')}, 'batch_dice': False}
#
# Plans were saved to C:\Users\clarynse\NasalSeg\nnUNet_preprocessed\Dataset123_NasalSeg\nnUNetPlans.json
# Preprocessing...
# Preprocessing dataset Dataset123_NasalSeg
# Configuration: 2d...
# Configuration: 3d_fullres...
# Configuration: 3d_lowres...
# INFO: Configuration 3d_lowres not found in plans file nnUNetPlans.json of dataset Dataset123_NasalSeg. Skipping.
#
#
#   0%|          | 0/130 [00:00<?, ?it/s]
#   1%|          | 1/130 [00:05<11:53,  5.53s/it]
#   2%|1         | 2/130 [00:05<05:06,  2.39s/it]
#   2%|2         | 3/130 [00:05<02:51,  1.35s/it]
#   3%|3         | 4/130 [00:05<01:47,  1.17it/s]
#   5%|4         | 6/130 [00:06<00:53,  2.33it/s]
#   6%|6         | 8/130 [00:06<00:35,  3.47it/s]
#   8%|7         | 10/130 [00:08<01:23,  1.43it/s]
#   8%|8         | 11/130 [00:09<01:10,  1.69it/s]
#   9%|9         | 12/130 [00:09<00:56,  2.10it/s]
#  10%|#         | 13/130 [00:09<00:47,  2.45it/s]
#  11%|#         | 14/130 [00:10<00:53,  2.17it/s]
#  12%|#1        | 15/130 [00:10<00:51,  2.25it/s]
#  12%|#2        | 16/130 [00:10<00:39,  2.87it/s]
#  13%|#3        | 17/130 [00:12<01:20,  1.41it/s]
#  14%|#3        | 18/130 [00:12<01:06,  1.69it/s]
#  15%|#4        | 19/130 [00:13<01:06,  1.68it/s]
#  16%|#6        | 21/130 [00:13<00:40,  2.70it/s]
#  17%|#6        | 22/130 [00:14<00:51,  2.09it/s]
#  18%|#8        | 24/130 [00:14<00:36,  2.91it/s]
#  19%|#9        | 25/130 [00:15<00:51,  2.02it/s]
#  20%|##        | 26/130 [00:16<01:07,  1.55it/s]
#  21%|##        | 27/130 [00:17<01:02,  1.64it/s]
#  22%|##1       | 28/130 [00:17<00:59,  1.72it/s]
#  22%|##2       | 29/130 [00:17<00:45,  2.23it/s]
#  23%|##3       | 30/130 [00:17<00:34,  2.87it/s]
#  24%|##3       | 31/130 [00:17<00:30,  3.26it/s]
#  25%|##4       | 32/130 [00:18<00:27,  3.62it/s]
#  25%|##5       | 33/130 [00:19<00:53,  1.81it/s]
#  26%|##6       | 34/130 [00:20<01:00,  1.59it/s]
